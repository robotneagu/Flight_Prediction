# %%
from pyspark.sql import SparkSession
# import pyspark.sql.functions as F
from pyspark.sql.functions import col, isnan, when, count, udf, to_date, year, month, date_format, size, split, datediff, regexp_extract, lit, abs
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler, OneHotEncoder, MinMaxScaler, StringIndexer
from pyspark.ml import Pipeline
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator, RegressionEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
cleaned_data_path = 'gs://my-bigdata-project-rn/cleaned/cleaned_itineraries.parquet'
#cleaned_data_path = '/Users/robertn/Desktop/2024Fall/CIS4130/cleaned_itineraries.parquet'
#Sample used to collect only 5% of random data. Will be adjusted
sdf = spark.read.parquet(cleaned_data_path, header=True, inferSchema=True)

# %%
#Ensure search and flight date are datetime values
sdf.printSchema()
# Out:
# root
#  |-- searchDate: date (nullable = true)
#  |-- flightDate: date (nullable = true)
#  |-- startingAirport: string (nullable = true)
#  |-- destinationAirport: string (nullable = true)
#  |-- travelDuration: string (nullable = true)
#  |-- elapsedDays: integer (nullable = true)
#  |-- isBasicEconomy: boolean (nullable = true)
#  |-- isNonStop: boolean (nullable = true)
#  |-- totalFare: double (nullable = true)
#  |-- seatsRemaining: integer (nullable = true)
#  |-- totalTravelDistance: integer (nullable = true)
#  |-- segmentsArrivalAirportCode: string (nullable = true)
#  |-- segmentsDepartureAirportCode: string (nullable = true)
#  |-- segmentsAirlineCode: string (nullable = true)
#  |-- segmentsEquipmentDescription: string (nullable = true)
#  |-- segmentsDurationInSeconds: string (nullable = true)
#  |-- segmentsDistance: string (nullable = true)
#  |-- segmentsCabinCode: string (nullable = true)

# %%
# Engineer additional date feature columns based on the order_date
# Goal is to have a flightDate_OnWeekend column
sdf = sdf.withColumn("flightDate_DayOfWeek", date_format(col("flightDate"), "EEEE"))         # 'Monday' 'Tuesday' etc.
sdf = sdf.withColumn("flightDate_OnWeekend", when(sdf.flightDate_DayOfWeek == 'Saturday',1.0).when(sdf.flightDate_DayOfWeek == 'Sunday', 1.0).otherwise(0).cast('int'))

# Check columns to see if we got good values
sdf.select(['flightDate','flightDate_DayOfWeek', 'flightDate_OnWeekend']).show(10)
# Out:
# +----------+--------------------+--------------------+
# |flightDate|flightDate_DayOfWeek|flightDate_OnWeekend|
# +----------+--------------------+--------------------+
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# +----------+--------------------+--------------------+
# only showing top 10 rows

# %%
#Create daysBetweenFlight column
sdf = sdf.withColumn("daysBetweenFlight", datediff(sdf.flightDate, sdf.searchDate))

# %%
#Create total travel duration column in a proper format
sdf = sdf.withColumn("travelduration_hours", regexp_extract(col("travelDuration"), r"(\d+)H",1).cast("int"))
sdf = sdf.withColumn("travelduration_minutes", regexp_extract(col("travelDuration"), r"(\d+)M",1).cast("int"))
sdf = sdf.na.fill(value=0.0,subset=["travelduration_minutes", "travelduration_hours"])
sdf = sdf.withColumn("travelduration_total_minutes", col("travelduration_hours") * 60 + col("travelduration_minutes"))

# %%
#Mapping true/false columns to 1 and 0
sdf = sdf.withColumn('isBasicEconomy', when(sdf.isBasicEconomy == 'true', 1).otherwise(0))
sdf = sdf.withColumn('isNonStop', when(sdf.isNonStop == 'true', 1).otherwise(0))

# %%
#Remove outlier elapsedDays values greater than 1
sdf = sdf.filter(col('elapsedDays') < 2)

# %%
#Verify no more outliers exist
sdf.groupBy('elapsedDays').count().show()
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +-----------+--------+
# |elapsedDays|   count|
# +-----------+--------+
# |          1|10943554|
# |          0|63810675|
# +-----------+--------+

# %%
#Apply MinMax to TotalTravelDistance
sdf = sdf.withColumn('totalTravelDistance', sdf.totalTravelDistance.cast('double'))
distance_assembler = VectorAssembler(inputCols=['totalTravelDistance'], outputCol='distanceVector')
totalDistance_scaler = MinMaxScaler(inputCol = 'distanceVector', outputCol = 'totalDistanceScaled')

#Indexer for string columns
indexer = StringIndexer(inputCols=['startingAirport', 'destinationAirport', 'segmentsArrivalAirportCode', 'segmentsCabinCode'], 
                        outputCols=['startAirportIndex', 'destAirportIndex', 'arrivalAirportCodeIndex', 'cabinCodeIndex'], handleInvalid="keep")

#One-Hot encoder
encoder = OneHotEncoder(inputCols=['startAirportIndex', 'destAirportIndex', 'arrivalAirportCodeIndex', 'cabinCodeIndex'],
                        outputCols=['startAirportVector', 'destAirportVector', 'arrivalAirportCodeVector', 'cabinCodeVector'],
                        dropLast=False)

#Creating the assembler for the feature vectors and integer columns used
assembler = VectorAssembler(inputCols=['startAirportVector', 'destAirportVector', 'arrivalAirportCodeVector', 'cabinCodeVector','daysBetweenFlight', 'flightDate_OnWeekend','travelduration_total_minutes', 'elapsedDays', 'isBasicEconomy', 'isNonStop', 'seatsRemaining', 'totalDistanceScaled'], outputCol='features')

# Create a Ridge Regression Estimator
ridge_reg = LinearRegression(labelCol='totalFare',  elasticNetParam=0, regParam=0.1)

# Create a regression evaluator (to get RMSE, R2, RME, etc.)
evaluator = RegressionEvaluator(labelCol='totalFare')

#Creating the pipeline

regression_pipe = Pipeline(stages=[indexer, encoder, distance_assembler, totalDistance_scaler, assembler, ridge_reg])

# Call .fit to transform the data
transformed_sdf = regression_pipe.fit(sdf).transform(sdf)

# Review the transformed features
print("Transformed features")
transformed_sdf.select('flightDate_OnWeekend', 'daysBetweenFlight','startingAirport','destinationAirport', 'travelduration_total_minutes', 'elapsedDays', 'isBasicEconomy', 'isNonStop', 'seatsRemaining', 'totalTravelDistance', 'segmentsArrivalAirportCode', 'segmentsCabinCode', 'totalFare', 'features').show(30, truncate=False)
# Out:
# 24/12/13 03:06:35 WARN DAGScheduler: Broadcasting large task binary with size 1837.8 KiB
# 24/12/13 03:07:43 WARN DAGScheduler: Broadcasting large task binary with size 1839.0 KiB
# 24/12/13 03:07:45 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:11 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:12 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:13 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:14 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:15 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:16 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:16 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:17 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:18 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:18 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:19 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:19 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:20 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:20 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:21 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:21 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:22 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:22 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:23 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:23 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:24 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:24 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:25 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:25 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:26 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:26 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:27 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:28 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:29 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:30 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:31 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:32 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:33 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:34 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:34 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:35 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:36 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:36 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:37 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:38 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:38 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:39 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:40 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:40 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:41 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:41 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:42 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:42 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:43 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:43 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:44 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:44 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:45 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:45 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:46 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:46 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:46 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:47 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:48 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:48 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 03:09:48 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 03:09:49 WARN DAGScheduler: Broadcasting large task binary with size 1907.1 KiB
# 24/12/13 03:10:52 WARN DAGScheduler: Broadcasting large task binary with size 1908.2 KiB
# Transformed features
# +--------------------+-----------------+---------------+------------------+----------------------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+---------------------------------------------------------------------------------------------------------------+
# |flightDate_OnWeekend|daysBetweenFlight|startingAirport|destinationAirport|travelduration_total_minutes|elapsedDays|isBasicEconomy|isNonStop|seatsRemaining|totalTravelDistance|segmentsArrivalAirportCode|segmentsCabinCode  |totalFare|features                                                                                                       |
# +--------------------+-----------------+---------------+------------------+----------------------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+---------------------------------------------------------------------------------------------------------------+
# |0                   |56               |MIA            |PHL               |469                         |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |358.6    |(10336,[9,28,54,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,469.0,9.0,0.16389780818092978])           |
# |0                   |56               |MIA            |PHL               |627                         |1          |0             |0        |4             |1059.0             |MCO||PHL                  |coach||coach       |359.61   |(10336,[9,28,248,10256,10328,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,627.0,1.0,4.0,0.13541812089906463])|
# |0                   |56               |MIA            |PHL               |550                         |0          |0             |0        |7             |1569.0             |JFK||BOS||PHL             |coach||coach||coach|367.1    |(10336,[9,28,299,10258,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,550.0,7.0,0.2066173391037275])           |
# |0                   |56               |MIA            |PHL               |311                         |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |398.6    |(10336,[9,28,54,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,311.0,9.0,0.16389780818092978])           |
# |0                   |56               |MIA            |PHL               |371                         |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |398.6    |(10336,[9,28,54,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,371.0,9.0,0.16389780818092978])           |
# |0                   |56               |MIA            |PHL               |404                         |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |398.6    |(10336,[9,28,54,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,404.0,9.0,0.16389780818092978])           |
# |0                   |56               |MIA            |PHL               |665                         |1          |0             |0        |7             |1059.0             |MCO||PHL                  |coach||coach       |416.2    |(10336,[9,28,248,10256,10328,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,665.0,1.0,7.0,0.13541812089906463])|
# |0                   |56               |MIA            |PHL               |269                         |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |498.6    |(10336,[9,28,54,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,269.0,9.0,0.16389780818092978])           |
# |0                   |56               |MIA            |PHL               |380                         |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |498.6    |(10336,[9,28,54,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,380.0,9.0,0.16389780818092978])           |
# |0                   |56               |MIA            |PHL               |891                         |1          |0             |0        |7             |1569.0             |JFK||BOS||PHL             |coach||coach||coach|519.9    |(10336,[9,28,299,10258,10328,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,891.0,1.0,7.0,0.2066173391037275]) |
# |0                   |56               |MIA            |PHL               |365                         |0          |0             |0        |3             |1201.0             |EWR||PHL                  |coach||coach       |523.6    |(10336,[9,28,116,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,365.0,3.0,0.15524221694820606])          |
# |0                   |56               |MIA            |PHL               |499                         |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |567.21   |(10336,[9,28,54,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,499.0,9.0,0.16389780818092978])           |
# |0                   |56               |MIA            |PHL               |317                         |0          |0             |0        |9             |1201.0             |EWR||PHL                  |coach||coach       |668.6    |(10336,[9,28,116,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,317.0,9.0,0.15524221694820606])          |
# |0                   |56               |MIA            |PHL               |364                         |0          |0             |0        |9             |1201.0             |EWR||PHL                  |coach||coach       |668.6    |(10336,[9,28,116,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,364.0,9.0,0.15524221694820606])          |
# |0                   |56               |MIA            |PHL               |647                         |0          |0             |0        |9             |1201.0             |EWR||PHL                  |coach||coach       |674.2    |(10336,[9,28,116,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,647.0,9.0,0.15524221694820606])          |
# |0                   |56               |MIA            |SFO               |801                         |1          |0             |0        |4             |2587.0             |LAS||SFO                  |coach||coach       |379.61   |(10336,[9,20,257,10256,10328,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,801.0,1.0,4.0,0.34873656289264277])|
# |0                   |56               |MIA            |SFO               |352                         |0          |0             |1        |7             |2582.0             |SFO                       |coach              |393.6    |(10336,[9,20,43,10257,10328,10330,10333,10334,10335],[1.0,1.0,1.0,1.0,56.0,352.0,1.0,7.0,0.34803853134161666]) |
# |0                   |56               |MIA            |SFO               |514                         |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |402.6    |(10336,[9,20,85,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,514.0,7.0,0.3481781376518219])            |
# |0                   |56               |MIA            |SFO               |611                         |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |402.6    |(10336,[9,20,85,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,611.0,7.0,0.3481781376518219])            |
# |0                   |56               |MIA            |SFO               |480                         |0          |0             |0        |1             |2621.0             |PHX||SFO                  |coach||coach       |437.6    |(10336,[9,20,95,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,480.0,1.0,0.35348317743962027])           |
# |0                   |56               |MIA            |SFO               |461                         |1          |0             |0        |4             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10328,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,461.0,1.0,4.0,0.3481781376518219])  |
# |0                   |56               |MIA            |SFO               |463                         |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,463.0,7.0,0.3481781376518219])            |
# |0                   |56               |MIA            |SFO               |506                         |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,506.0,7.0,0.3481781376518219])            |
# |0                   |56               |MIA            |SFO               |523                         |0          |0             |0        |1             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,523.0,1.0,0.3481781376518219])            |
# |0                   |56               |MIA            |SFO               |544                         |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,544.0,7.0,0.3481781376518219])            |
# |0                   |56               |MIA            |SFO               |604                         |0          |0             |0        |1             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,604.0,1.0,0.3481781376518219])            |
# |0                   |56               |MIA            |SFO               |724                         |0          |0             |0        |7             |3670.0             |JFK||SFO                  |coach||coach       |469.61   |(10336,[9,20,78,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,724.0,7.0,0.4999301968448974])            |
# |0                   |56               |MIA            |SFO               |952                         |0          |0             |0        |7             |3089.0             |MSP||SFO                  |coach||coach       |477.2    |(10336,[9,20,168,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,952.0,7.0,0.41881893061566383])          |
# |0                   |56               |MIA            |SFO               |545                         |0          |0             |0        |9             |2685.0             |SLC||SFO                  |coach||coach       |518.61   |(10336,[9,20,127,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,545.0,9.0,0.36241798129275443])          |
# |0                   |56               |MIA            |SFO               |605                         |0          |0             |0        |9             |2731.0             |ATL||SFO                  |coach||coach       |518.61   |(10336,[9,20,111,10256,10328,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,605.0,9.0,0.3688398715621946])           |
# +--------------------+-----------------+---------------+------------------+----------------------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+---------------------------------------------------------------------------------------------------------------+
# only showing top 30 rows

# %%
# Split the data into 70% training and 30% test sets  
trainingData, testData = sdf.randomSplit([0.7, 0.3], seed=42)

# Create a grid to hold hyperparameters 
grid = ParamGridBuilder()

# Build the parameter grid
grid = grid.build()

# Create the CrossValidator using the hyperparameter grid
cv = CrossValidator(estimator=regression_pipe, 
                    estimatorParamMaps=grid, 
                    evaluator=evaluator, 
                    numFolds=3)

# Train the models
all_models  = cv.fit(trainingData)

# Show the average performance over the three folds
print(f"Average metric {all_models.avgMetrics}")

# Get the best model from all of the models trained
bestModel = all_models.bestModel

# Use the model 'bestModel' to predict the test set
test_results = bestModel.transform(testData)
# Show the predicted tip
test_results.select('flightDate_OnWeekend', 'daysBetweenFlight','startingAirport','destinationAirport', 'travelduration_total_minutes', 'elapsedDays', 'isBasicEconomy', 'isNonStop', 'seatsRemaining', 'totalTravelDistance', 'segmentsArrivalAirportCode', 'segmentsCabinCode', 'totalFare', 'prediction').show(truncate=False)
# Calculate RMSE and R2
rmse = evaluator.evaluate(test_results, {evaluator.metricName:'rmse'})
r2 =evaluator.evaluate(test_results,{evaluator.metricName:'r2'})
print(f"RMSE: {rmse}  R-squared:{r2}")
# Out:
# 24/12/13 03:12:06 WARN DAGScheduler: Broadcasting large task binary with size 1748.3 KiB
# 24/12/13 03:12:30 WARN DAGScheduler: Broadcasting large task binary with size 1749.6 KiB
# 24/12/13 03:12:30 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:12:56 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:12:56 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:12:56 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:12:56 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:12:57 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:12:57 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:12:57 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:12:57 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:12:58 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:12:58 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:12:58 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:12:58 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:12:59 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:12:59 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:12:59 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:12:59 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:00 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:00 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:00 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:00 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:01 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:01 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:01 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:02 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:02 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:02 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:02 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:03 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:03 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:03 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:03 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:04 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:04 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:04 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:04 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:04 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:05 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:05 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:05 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:06 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:06 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:06 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:06 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:06 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:07 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:08 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:09 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:10 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:11 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:12 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:13 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 03:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 03:13:14 WARN DAGScheduler: Broadcasting large task binary with size 1811.8 KiB
# 24/12/13 03:13:35 WARN DAGScheduler: Broadcasting large task binary with size 1812.9 KiB
# 24/12/13 03:14:24 WARN DAGScheduler: Broadcasting large task binary with size 1812.4 KiB
# 24/12/13 03:14:36 WARN DAGScheduler: Broadcasting large task binary with size 1813.5 KiB
# 24/12/13 03:15:45 WARN DAGScheduler: Broadcasting large task binary with size 1748.1 KiB
# 24/12/13 03:16:09 WARN DAGScheduler: Broadcasting large task binary with size 1749.3 KiB
# 24/12/13 03:16:09 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:35 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:35 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:36 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:36 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:36 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:36 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:36 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:37 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:37 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:37 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:37 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:38 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:38 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:38 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:38 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:39 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:39 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:39 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:39 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:39 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:40 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:40 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:40 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:41 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:41 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:41 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:41 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:41 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:42 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:42 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:42 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:42 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:43 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:43 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:43 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:43 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:44 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:45 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:46 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:47 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:48 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:49 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:50 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:51 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:52 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:52 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 03:16:52 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 03:16:52 WARN DAGScheduler: Broadcasting large task binary with size 1811.6 KiB
# 24/12/13 03:17:13 WARN DAGScheduler: Broadcasting large task binary with size 1812.7 KiB
# 24/12/13 03:18:01 WARN DAGScheduler: Broadcasting large task binary with size 1812.1 KiB
# 24/12/13 03:18:12 WARN DAGScheduler: Broadcasting large task binary with size 1813.3 KiB
# 24/12/13 03:19:22 WARN DAGScheduler: Broadcasting large task binary with size 1754.4 KiB
# 24/12/13 03:19:47 WARN DAGScheduler: Broadcasting large task binary with size 1755.6 KiB
# 24/12/13 03:19:47 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:12 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:12 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:13 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:13 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:13 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:13 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:13 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:14 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:14 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:14 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:14 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:15 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:15 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:15 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:15 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:16 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:16 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:16 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:16 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:16 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:17 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:17 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:17 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:17 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:18 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:18 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:18 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:18 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:18 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:19 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:19 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:19 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:19 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:19 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:20 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:20 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:20 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:20 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:21 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:21 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:21 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:21 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:22 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:22 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:22 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:22 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:23 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:23 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:23 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:23 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:24 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:24 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:24 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:24 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:25 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:25 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:25 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:25 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:25 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:26 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:26 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:26 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:26 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:26 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:27 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:27 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:27 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:27 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:28 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:28 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:28 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:28 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 03:20:29 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 03:20:29 WARN DAGScheduler: Broadcasting large task binary with size 1818.2 KiB
# 24/12/13 03:20:49 WARN DAGScheduler: Broadcasting large task binary with size 1819.3 KiB
# 24/12/13 03:21:37 WARN DAGScheduler: Broadcasting large task binary with size 1818.7 KiB
# 24/12/13 03:21:49 WARN DAGScheduler: Broadcasting large task binary with size 1819.8 KiB
# 24/12/13 03:23:01 WARN DAGScheduler: Broadcasting large task binary with size 1794.6 KiB
# 24/12/13 03:24:08 WARN DAGScheduler: Broadcasting large task binary with size 1795.8 KiB
# 24/12/13 03:24:09 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:39 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:39 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:40 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:40 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:40 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:41 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:42 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:43 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:44 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:45 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:46 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:47 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:48 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:49 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:49 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:49 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:49 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:50 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:50 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:50 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:51 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:51 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:51 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:51 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:52 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:52 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:52 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:52 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:53 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:53 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:54 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:54 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:54 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:54 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:55 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:55 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:55 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:55 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:56 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:56 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:56 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:56 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:57 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:57 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:57 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:58 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:58 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:58 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:58 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:59 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:25:59 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:25:59 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:26:00 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:26:00 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 03:26:00 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 03:26:00 WARN DAGScheduler: Broadcasting large task binary with size 1861.0 KiB
# 24/12/13 03:27:00 WARN DAGScheduler: Broadcasting large task binary with size 1862.1 KiB
# Average metric [126.5802749971769]
# 24/12/13 03:27:01 WARN DAGScheduler: Broadcasting large task binary with size 1855.3 KiB
# +--------------------+-----------------+---------------+------------------+----------------------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+------------------+
# |flightDate_OnWeekend|daysBetweenFlight|startingAirport|destinationAirport|travelduration_total_minutes|elapsedDays|isBasicEconomy|isNonStop|seatsRemaining|totalTravelDistance|segmentsArrivalAirportCode|segmentsCabinCode  |totalFare|prediction        |
# +--------------------+-----------------+---------------+------------------+----------------------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+------------------+
# |1                   |40               |ORD            |MIA               |186                         |0          |0             |1        |2             |1192.0             |MIA                       |coach              |338.61   |230.2703043663888 |
# |1                   |40               |ORD            |MIA               |382                         |0          |0             |0        |7             |1824.0             |JFK||MIA                  |coach||coach       |347.61   |292.64091678816135|
# |1                   |40               |ORD            |MIA               |388                         |0          |0             |0        |9             |1824.0             |LGA||MIA                  |coach||coach       |328.6    |326.35061111776986|
# |1                   |40               |ORD            |MIA               |395                         |0          |0             |0        |9             |1196.0             |ATL||MIA                  |coach||coach       |328.6    |383.02697305989807|
# |1                   |40               |ORD            |MIA               |443                         |0          |0             |0        |9             |1824.0             |EWR||MIA                  |coach||coach       |357.6    |398.67776161400474|
# |1                   |40               |ORD            |MIA               |450                         |0          |0             |0        |7             |1824.0             |JFK||MIA                  |coach||coach       |347.61   |297.29257938543503|
# |1                   |40               |ORD            |MIA               |425                         |0          |0             |0        |9             |1824.0             |EWR||MIA                  |coach||coach       |357.6    |397.44643916178524|
# |1                   |40               |ORD            |OAK               |627                         |0          |0             |0        |3             |2285.0             |PDX||OAK                  |coach||coach       |547.2    |529.043416276941  |
# |1                   |40               |ORD            |OAK               |653                         |0          |0             |0        |2             |1839.0             |SLC||OAK                  |coach||coach       |667.2    |483.61632873220367|
# |1                   |40               |ORD            |OAK               |720                         |0          |0             |0        |9             |2213.0             |MSP||LAX||OAK             |coach||coach||coach|725.1    |553.2970150069909 |
# |1                   |40               |ORD            |OAK               |720                         |0          |0             |0        |9             |2213.0             |MSP||LAX||OAK             |coach||coach||coach|725.1    |553.2970150069909 |
# |1                   |40               |ORD            |OAK               |902                         |1          |0             |0        |9             |2636.0             |AUS||SLC||OAK             |coach||coach||coach|767.7    |586.3781837735576 |
# |1                   |40               |ORD            |OAK               |1079                        |0          |0             |0        |7             |2612.0             |SLC||SEA||OAK             |coach||coach||coach|666.09   |605.4853420748938 |
# |1                   |40               |ORD            |OAK               |1109                        |0          |0             |0        |5             |2592.0             |DEN||SEA||OAK             |coach||coach||coach|636.09   |561.5121016191384 |
# |1                   |40               |ORD            |OAK               |442                         |0          |0             |0        |7             |2285.0             |PDX||OAK                  |coach||coach       |627.6    |531.6009896598437 |
# |1                   |40               |ORD            |OAK               |499                         |0          |0             |0        |7             |2395.0             |SEA||OAK                  |coach||coach       |627.6    |520.902887825744  |
# |1                   |40               |ORD            |OAK               |506                         |0          |0             |0        |3             |2285.0             |PDX||OAK                  |coach||coach       |611.6    |520.7661931259099 |
# |1                   |40               |ORD            |OAK               |595                         |0          |0             |0        |9             |1919.0             |MSP||SLC||OAK             |coach||coach||coach|725.1    |658.7155222249381 |
# |1                   |40               |ORD            |PHL               |644                         |1          |0             |0        |7             |1142.0             |BOS||PHL                  |coach||coach       |312.19   |318.6731147091552 |
# |1                   |40               |ORD            |PHL               |690                         |1          |0             |0        |6             |1142.0             |BOS||PHL                  |coach||coach       |312.19   |318.0166196627043 |
# +--------------------+-----------------+---------------+------------------+----------------------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+------------------+
# only showing top 20 rows
# 24/12/13 03:27:18 WARN DAGScheduler: Broadcasting large task binary with size 1861.8 KiB
# 24/12/13 03:28:01 WARN DAGScheduler: Broadcasting large task binary with size 1862.9 KiB
# 24/12/13 03:28:01 WARN DAGScheduler: Broadcasting large task binary with size 1861.8 KiB
# [Stage 441:===================================================>   (17 + 1) / 18]
# RMSE: 126.42190553009543  R-squared:0.5888453561622946
# 24/12/13 03:28:44 WARN DAGScheduler: Broadcasting large task binary with size 1862.9 KiB

# %%
print(bestModel.stages)

coefficients = bestModel.stages[5].coefficients
# print("bestModel coefficients", coefficients)
intercept = bestModel.stages[5].intercept
print("bestModel intercept", intercept)

#Finding the most important features
feature_names = ['daysBetweenFlight','flightDate_OnWeekend','startingAirport','destinationAirport', 'travelduration_total_minutes', 'elapsedDays', 'isBasicEconomy', 'isNonStop', 'seatsRemaining', 'totalTravelDistance', 'segmentsArrivalAirportCode', 'segmentsCabinCode']

coef_map = dict(zip(feature_names, coefficients))

print("Feature Importance:")
for feature, coef in coef_map.items():
    print("  {}: {:.3f}".format(feature, coef))

# %%
transformed_sdf.write.parquet('gs://my-bigdata-project-rn/trusted/trusted_ridge_itineraries.parquet')
# Out:
# 24/12/13 03:28:44 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/12/13 03:28:45 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# [Stage 443:=====================>                                 (7 + 11) / 18]

# %%
model_path =  'gs://my-bigdata-project-rn/models/plane_ridge_regression_model'
bestModel.write().overwrite().save(model_path)
