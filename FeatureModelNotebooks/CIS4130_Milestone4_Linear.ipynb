# %%
from pyspark.sql import SparkSession
# import pyspark.sql.functions as F
from pyspark.sql.functions import col, isnan, when, count, udf, to_date, year, month, date_format, size, split, datediff, regexp_extract, lit, abs
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler, OneHotEncoder, MinMaxScaler, StringIndexer
from pyspark.ml import Pipeline
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator, RegressionEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://cluster-5f6a-m.us-central1-f.c.semester-project-fall-2024.internal:41991">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
cleaned_data_path = 'gs://my-bigdata-project-rn/cleaned/cleaned_itineraries.parquet'
#cleaned_data_path = '/Users/robertn/Desktop/2024Fall/CIS4130/cleaned_itineraries.parquet'
#Sample used to collect only 5% of random data. Will be adjusted
sdf = spark.read.parquet(cleaned_data_path, header=True, inferSchema=True)

# %%
#Ensure search and flight date are datetime values
sdf.printSchema()
# Out:
# root
#  |-- searchDate: date (nullable = true)
#  |-- flightDate: date (nullable = true)
#  |-- startingAirport: string (nullable = true)
#  |-- destinationAirport: string (nullable = true)
#  |-- travelDuration: string (nullable = true)
#  |-- elapsedDays: integer (nullable = true)
#  |-- isBasicEconomy: boolean (nullable = true)
#  |-- isNonStop: boolean (nullable = true)
#  |-- totalFare: double (nullable = true)
#  |-- seatsRemaining: integer (nullable = true)
#  |-- totalTravelDistance: integer (nullable = true)
#  |-- segmentsArrivalAirportCode: string (nullable = true)
#  |-- segmentsDepartureAirportCode: string (nullable = true)
#  |-- segmentsAirlineCode: string (nullable = true)
#  |-- segmentsEquipmentDescription: string (nullable = true)
#  |-- segmentsDurationInSeconds: string (nullable = true)
#  |-- segmentsDistance: string (nullable = true)
#  |-- segmentsCabinCode: string (nullable = true)

# %%
# Engineer additional date feature columns based on the order_date
# Goal is to have a flightDate_OnWeekend column
sdf = sdf.withColumn("flightDate_DayOfWeek", date_format(col("flightDate"), "EEEE"))         # 'Monday' 'Tuesday' etc.
sdf = sdf.withColumn("flightDate_OnWeekend", when(sdf.flightDate_DayOfWeek == 'Saturday',1.0).when(sdf.flightDate_DayOfWeek == 'Sunday', 1.0).otherwise(0).cast('int'))

# Check columns to see if we got good values
sdf.select(['flightDate','flightDate_DayOfWeek', 'flightDate_OnWeekend']).show(10)
# Out:
# +----------+--------------------+--------------------+
# |flightDate|flightDate_DayOfWeek|flightDate_OnWeekend|
# +----------+--------------------+--------------------+
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# |2022-07-01|              Friday|                   0|
# +----------+--------------------+--------------------+
# only showing top 10 rows

# %%
#Create daysBetweenFlight column
sdf = sdf.withColumn("daysBetweenFlight", datediff(sdf.flightDate, sdf.searchDate))

# %%
#Create total travel duration column in a proper format
sdf = sdf.withColumn("travelduration_hours", regexp_extract(col("travelDuration"), r"(\d+)H",1).cast("int"))
sdf = sdf.withColumn("travelduration_minutes", regexp_extract(col("travelDuration"), r"(\d+)M",1).cast("int"))
sdf = sdf.na.fill(value=0.0,subset=["travelduration_minutes", "travelduration_hours"])
sdf = sdf.withColumn("travelduration_total_minutes", col("travelduration_hours") * 60 + col("travelduration_minutes"))

# %%
#Mapping true/false columns to 1 and 0
sdf = sdf.withColumn('isBasicEconomy', when(sdf.isBasicEconomy == 'true', 1).otherwise(0))
sdf = sdf.withColumn('isNonStop', when(sdf.isNonStop == 'true', 1).otherwise(0))

# %%
#Remove outlier elapsedDays values greater than 1
sdf = sdf.filter(col('elapsedDays') < 2)

# %%
#Verify no more outliers exist
sdf.groupBy('elapsedDays').count().show()
# Out:
# [Stage 7:=====================================================>   (15 + 1) / 16]
# +-----------+--------+
# |elapsedDays|   count|
# +-----------+--------+
# |          1|10943554|
# |          0|63810675|
# +-----------+--------+

# %%
#Apply MinMax to TotalTravelDistance
sdf = sdf.withColumn('totalTravelDistance', sdf.totalTravelDistance.cast('double'))
distance_assembler = VectorAssembler(inputCols=['totalTravelDistance'], outputCol='distanceVector')
totalDistance_scaler = MinMaxScaler(inputCol = 'distanceVector', outputCol = 'totalDistanceScaled')

#Indexer for string columns
indexer = StringIndexer(inputCols=['startingAirport', 'destinationAirport', 'segmentsArrivalAirportCode', 'segmentsCabinCode'], 
                        outputCols=['startAirportIndex', 'destAirportIndex', 'arrivalAirportCodeIndex', 'cabinCodeIndex'], handleInvalid="keep")

#One-Hot encoder
encoder = OneHotEncoder(inputCols=['startAirportIndex', 'destAirportIndex', 'arrivalAirportCodeIndex', 'cabinCodeIndex'],
                        outputCols=['startAirportVector', 'destAirportVector', 'arrivalAirportCodeVector', 'cabinCodeVector'],
                        dropLast=False)

#Creating the assembler for the feature vectors and integer columns used
assembler = VectorAssembler(inputCols=['startAirportVector', 'destAirportVector', 'arrivalAirportCodeVector', 'cabinCodeVector', 'flightDate_OnWeekend', 'daysBetweenFlight', 'travelduration_total_minutes', 'elapsedDays', 'isBasicEconomy', 'isNonStop', 'seatsRemaining', 'totalDistanceScaled'], outputCol='features')

# Create a Linear Regression Estimator
linear_reg = LinearRegression(labelCol='totalFare')

# Create a regression evaluator (to get RMSE, R2, RME, etc.)
evaluator = RegressionEvaluator(labelCol='totalFare')

#Creating the pipeline

regression_pipe = Pipeline(stages=[indexer, encoder, distance_assembler, totalDistance_scaler, assembler, linear_reg])

# Call .fit to transform the data
transformed_sdf = regression_pipe.fit(sdf).transform(sdf)

# Review the transformed features
print("Transformed features")
transformed_sdf.select('flightDate_OnWeekend','startingAirport','destinationAirport', 'travelduration_total_minutes', 'daysBetweenFlight', 'elapsedDays', 'isBasicEconomy', 'isNonStop', 'seatsRemaining', 'totalTravelDistance', 'segmentsArrivalAirportCode', 'segmentsCabinCode', 'totalFare', 'features').show(30, truncate=False)
# Out:
# 24/12/13 02:33:45 WARN DAGScheduler: Broadcasting large task binary with size 1837.8 KiB
# 24/12/13 02:34:54 WARN DAGScheduler: Broadcasting large task binary with size 1839.0 KiB
# 24/12/13 02:34:57 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:24 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:24 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:25 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:26 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:26 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:27 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:28 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:28 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:29 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:29 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:30 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:30 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:31 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:32 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:32 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:33 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:33 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:34 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:34 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:35 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:35 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:36 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:37 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:37 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:38 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:38 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:39 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:39 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:40 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:40 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:41 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:41 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:42 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:42 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:43 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:43 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:44 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:44 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:45 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:45 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:46 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:46 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:47 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:47 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:48 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:48 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:49 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:49 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:50 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:50 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:51 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:51 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:52 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:52 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:53 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:53 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:54 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:54 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:55 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:55 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:56 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:56 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:57 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:57 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:58 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:58 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:36:59 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:36:59 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:37:00 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:37:00 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:37:01 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:37:01 WARN DAGScheduler: Broadcasting large task binary with size 1838.3 KiB
# 24/12/13 02:37:02 WARN DAGScheduler: Broadcasting large task binary with size 1839.5 KiB
# 24/12/13 02:37:02 WARN DAGScheduler: Broadcasting large task binary with size 1907.0 KiB
# 24/12/13 02:38:06 WARN DAGScheduler: Broadcasting large task binary with size 1908.2 KiB
# Transformed features
# +--------------------+---------------+------------------+----------------------------+-----------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+---------------------------------------------------------------------------------------------------------------+
# |flightDate_OnWeekend|startingAirport|destinationAirport|travelduration_total_minutes|daysBetweenFlight|elapsedDays|isBasicEconomy|isNonStop|seatsRemaining|totalTravelDistance|segmentsArrivalAirportCode|segmentsCabinCode  |totalFare|features                                                                                                       |
# +--------------------+---------------+------------------+----------------------------+-----------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+---------------------------------------------------------------------------------------------------------------+
# |0                   |MIA            |PHL               |469                         |56               |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |358.6    |(10336,[9,28,54,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,469.0,9.0,0.16389780818092978])           |
# |0                   |MIA            |PHL               |627                         |56               |1          |0             |0        |4             |1059.0             |MCO||PHL                  |coach||coach       |359.61   |(10336,[9,28,248,10256,10329,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,627.0,1.0,4.0,0.13541812089906463])|
# |0                   |MIA            |PHL               |550                         |56               |0          |0             |0        |7             |1569.0             |JFK||BOS||PHL             |coach||coach||coach|367.1    |(10336,[9,28,299,10258,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,550.0,7.0,0.2066173391037275])           |
# |0                   |MIA            |PHL               |311                         |56               |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |398.6    |(10336,[9,28,54,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,311.0,9.0,0.16389780818092978])           |
# |0                   |MIA            |PHL               |371                         |56               |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |398.6    |(10336,[9,28,54,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,371.0,9.0,0.16389780818092978])           |
# |0                   |MIA            |PHL               |404                         |56               |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |398.6    |(10336,[9,28,54,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,404.0,9.0,0.16389780818092978])           |
# |0                   |MIA            |PHL               |665                         |56               |1          |0             |0        |7             |1059.0             |MCO||PHL                  |coach||coach       |416.2    |(10336,[9,28,248,10256,10329,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,665.0,1.0,7.0,0.13541812089906463])|
# |0                   |MIA            |PHL               |269                         |56               |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |498.6    |(10336,[9,28,54,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,269.0,9.0,0.16389780818092978])           |
# |0                   |MIA            |PHL               |380                         |56               |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |498.6    |(10336,[9,28,54,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,380.0,9.0,0.16389780818092978])           |
# |0                   |MIA            |PHL               |891                         |56               |1          |0             |0        |7             |1569.0             |JFK||BOS||PHL             |coach||coach||coach|519.9    |(10336,[9,28,299,10258,10329,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,891.0,1.0,7.0,0.2066173391037275]) |
# |0                   |MIA            |PHL               |365                         |56               |0          |0             |0        |3             |1201.0             |EWR||PHL                  |coach||coach       |523.6    |(10336,[9,28,116,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,365.0,3.0,0.15524221694820606])          |
# |0                   |MIA            |PHL               |499                         |56               |0          |0             |0        |9             |1263.0             |ATL||PHL                  |coach||coach       |567.21   |(10336,[9,28,54,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,499.0,9.0,0.16389780818092978])           |
# |0                   |MIA            |PHL               |317                         |56               |0          |0             |0        |9             |1201.0             |EWR||PHL                  |coach||coach       |668.6    |(10336,[9,28,116,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,317.0,9.0,0.15524221694820606])          |
# |0                   |MIA            |PHL               |364                         |56               |0          |0             |0        |9             |1201.0             |EWR||PHL                  |coach||coach       |668.6    |(10336,[9,28,116,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,364.0,9.0,0.15524221694820606])          |
# |0                   |MIA            |PHL               |647                         |56               |0          |0             |0        |9             |1201.0             |EWR||PHL                  |coach||coach       |674.2    |(10336,[9,28,116,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,647.0,9.0,0.15524221694820606])          |
# |0                   |MIA            |SFO               |801                         |56               |1          |0             |0        |4             |2587.0             |LAS||SFO                  |coach||coach       |379.61   |(10336,[9,20,257,10256,10329,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,801.0,1.0,4.0,0.34873656289264277])|
# |0                   |MIA            |SFO               |352                         |56               |0          |0             |1        |7             |2582.0             |SFO                       |coach              |393.6    |(10336,[9,20,43,10257,10329,10330,10333,10334,10335],[1.0,1.0,1.0,1.0,56.0,352.0,1.0,7.0,0.34803853134161666]) |
# |0                   |MIA            |SFO               |514                         |56               |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |402.6    |(10336,[9,20,85,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,514.0,7.0,0.3481781376518219])            |
# |0                   |MIA            |SFO               |611                         |56               |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |402.6    |(10336,[9,20,85,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,611.0,7.0,0.3481781376518219])            |
# |0                   |MIA            |SFO               |480                         |56               |0          |0             |0        |1             |2621.0             |PHX||SFO                  |coach||coach       |437.6    |(10336,[9,20,95,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,480.0,1.0,0.35348317743962027])           |
# |0                   |MIA            |SFO               |461                         |56               |1          |0             |0        |4             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10329,10330,10331,10334,10335],[1.0,1.0,1.0,1.0,56.0,461.0,1.0,4.0,0.3481781376518219])  |
# |0                   |MIA            |SFO               |463                         |56               |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,463.0,7.0,0.3481781376518219])            |
# |0                   |MIA            |SFO               |506                         |56               |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,506.0,7.0,0.3481781376518219])            |
# |0                   |MIA            |SFO               |523                         |56               |0          |0             |0        |1             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,523.0,1.0,0.3481781376518219])            |
# |0                   |MIA            |SFO               |544                         |56               |0          |0             |0        |7             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,544.0,7.0,0.3481781376518219])            |
# |0                   |MIA            |SFO               |604                         |56               |0          |0             |0        |1             |2583.0             |DFW||SFO                  |coach||coach       |467.6    |(10336,[9,20,85,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,604.0,1.0,0.3481781376518219])            |
# |0                   |MIA            |SFO               |724                         |56               |0          |0             |0        |7             |3670.0             |JFK||SFO                  |coach||coach       |469.61   |(10336,[9,20,78,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,724.0,7.0,0.4999301968448974])            |
# |0                   |MIA            |SFO               |952                         |56               |0          |0             |0        |7             |3089.0             |MSP||SFO                  |coach||coach       |477.2    |(10336,[9,20,168,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,952.0,7.0,0.41881893061566383])          |
# |0                   |MIA            |SFO               |545                         |56               |0          |0             |0        |9             |2685.0             |SLC||SFO                  |coach||coach       |518.61   |(10336,[9,20,127,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,545.0,9.0,0.36241798129275443])          |
# |0                   |MIA            |SFO               |605                         |56               |0          |0             |0        |9             |2731.0             |ATL||SFO                  |coach||coach       |518.61   |(10336,[9,20,111,10256,10329,10330,10334,10335],[1.0,1.0,1.0,1.0,56.0,605.0,9.0,0.3688398715621946])           |
# +--------------------+---------------+------------------+----------------------------+-----------------+-----------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+---------------------------------------------------------------------------------------------------------------+
# only showing top 30 rows

# %%
# Split the data into 70% training and 30% test sets  
trainingData, testData = sdf.randomSplit([0.7, 0.3], seed=42)

# Create a grid to hold hyperparameters 
grid = ParamGridBuilder()

# Build the parameter grid
grid = grid.build()

# Create the CrossValidator using the hyperparameter grid
cv = CrossValidator(estimator=regression_pipe, 
                    estimatorParamMaps=grid, 
                    evaluator=evaluator, 
                    numFolds=3)

# Train the models
all_models  = cv.fit(trainingData)

# Show the average performance over the three folds
print(f"Average metric {all_models.avgMetrics}")

# Get the best model from all of the models trained
bestModel = all_models.bestModel

# Use the model 'bestModel' to predict the test set
test_results = bestModel.transform(testData)
# Show the predicted tip
test_results.select('flightDate_OnWeekend','startingAirport','destinationAirport', 'travelduration_total_minutes', 'elapsedDays', 'daysBetweenFlight', 'isBasicEconomy', 'isNonStop', 'seatsRemaining', 'totalTravelDistance', 'segmentsArrivalAirportCode', 'segmentsCabinCode', 'totalFare', 'prediction').show(truncate=False)
# Calculate RMSE and R2
rmse = evaluator.evaluate(test_results, {evaluator.metricName:'rmse'})
r2 =evaluator.evaluate(test_results,{evaluator.metricName:'r2'})
print(f"RMSE: {rmse}  R-squared:{r2}")
# Out:
# 24/12/13 02:39:24 WARN DAGScheduler: Broadcasting large task binary with size 1748.3 KiB
# 24/12/13 02:39:48 WARN DAGScheduler: Broadcasting large task binary with size 1749.6 KiB
# 24/12/13 02:39:48 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:14 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:14 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:15 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:15 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:15 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:15 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:15 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:16 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:16 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:16 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:16 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:17 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:17 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:17 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:17 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:18 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:18 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:18 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:18 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:19 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:19 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:19 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:20 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:20 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:20 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:20 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:21 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:21 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:21 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:21 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:22 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:22 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:22 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:22 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:23 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:23 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:23 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:23 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:24 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:24 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:24 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:24 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:25 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:25 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:25 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:25 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:26 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:26 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:26 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:26 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:27 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:27 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:27 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:27 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:28 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:28 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:28 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:28 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:28 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:29 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:29 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:29 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:29 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:30 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:30 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:30 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:30 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:31 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:31 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:31 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:31 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:32 WARN DAGScheduler: Broadcasting large task binary with size 1748.8 KiB
# 24/12/13 02:40:32 WARN DAGScheduler: Broadcasting large task binary with size 1750.0 KiB
# 24/12/13 02:40:32 WARN DAGScheduler: Broadcasting large task binary with size 1811.8 KiB
# 24/12/13 02:40:54 WARN DAGScheduler: Broadcasting large task binary with size 1812.9 KiB
# 24/12/13 02:41:42 WARN DAGScheduler: Broadcasting large task binary with size 1812.3 KiB
# 24/12/13 02:41:55 WARN DAGScheduler: Broadcasting large task binary with size 1813.5 KiB
# 24/12/13 02:43:05 WARN DAGScheduler: Broadcasting large task binary with size 1748.1 KiB
# 24/12/13 02:43:29 WARN DAGScheduler: Broadcasting large task binary with size 1749.3 KiB
# 24/12/13 02:43:29 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:55 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:55 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:55 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:55 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:56 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:57 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:57 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:57 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:57 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:58 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:58 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:58 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:58 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:58 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:59 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:59 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:43:59 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:43:59 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:00 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:00 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:00 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:00 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:00 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:01 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:01 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:01 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:01 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:02 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:02 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:02 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:02 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:03 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:03 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:03 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:03 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:04 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:04 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:04 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:04 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:05 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:05 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:05 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:05 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:05 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:06 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:07 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:08 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:09 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:10 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1748.6 KiB
# 24/12/13 02:44:11 WARN DAGScheduler: Broadcasting large task binary with size 1749.8 KiB
# 24/12/13 02:44:12 WARN DAGScheduler: Broadcasting large task binary with size 1811.6 KiB
# 24/12/13 02:44:34 WARN DAGScheduler: Broadcasting large task binary with size 1812.7 KiB
# 24/12/13 02:45:23 WARN DAGScheduler: Broadcasting large task binary with size 1812.1 KiB
# 24/12/13 02:45:35 WARN DAGScheduler: Broadcasting large task binary with size 1813.2 KiB
# 24/12/13 02:46:42 WARN DAGScheduler: Broadcasting large task binary with size 1754.4 KiB
# 24/12/13 02:47:06 WARN DAGScheduler: Broadcasting large task binary with size 1755.6 KiB
# 24/12/13 02:47:07 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:32 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:32 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:33 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:33 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:33 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:33 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:34 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:34 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:34 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:34 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:35 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:35 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:35 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:35 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:35 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:36 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:36 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:36 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:36 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:36 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:37 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:37 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:37 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:37 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:38 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:38 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:38 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:38 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:39 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:39 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:39 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:39 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:39 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:40 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:40 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:40 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:40 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:41 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:41 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:41 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:41 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:42 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:42 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:42 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:42 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:42 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:43 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:43 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:43 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:43 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:44 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:44 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:44 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:44 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:45 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:45 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:45 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:45 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:46 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:46 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:46 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:46 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:46 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:47 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:47 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:47 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:47 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:47 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:48 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:48 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:48 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:48 WARN DAGScheduler: Broadcasting large task binary with size 1754.9 KiB
# 24/12/13 02:47:49 WARN DAGScheduler: Broadcasting large task binary with size 1756.1 KiB
# 24/12/13 02:47:49 WARN DAGScheduler: Broadcasting large task binary with size 1818.1 KiB
# 24/12/13 02:48:11 WARN DAGScheduler: Broadcasting large task binary with size 1819.3 KiB
# 24/12/13 02:49:00 WARN DAGScheduler: Broadcasting large task binary with size 1818.7 KiB
# 24/12/13 02:49:12 WARN DAGScheduler: Broadcasting large task binary with size 1819.8 KiB
# 24/12/13 02:50:25 WARN DAGScheduler: Broadcasting large task binary with size 1794.6 KiB
# 24/12/13 02:51:37 WARN DAGScheduler: Broadcasting large task binary with size 1795.8 KiB
# 24/12/13 02:51:37 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:12 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:12 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:13 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:13 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:13 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:14 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:14 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:14 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:15 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:15 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:16 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:16 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:16 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:16 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:17 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:17 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:18 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:18 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:18 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:18 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:19 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:19 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:20 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:20 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:20 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:20 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:21 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:21 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:21 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:21 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:22 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:22 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:22 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:23 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:23 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:23 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:24 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:24 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:24 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:24 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:25 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:25 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:25 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:25 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:26 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:26 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:26 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:27 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:27 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:27 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:28 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:28 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:28 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:28 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:29 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:29 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:29 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:29 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:30 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:30 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:30 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:31 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:31 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:31 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:32 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:32 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:32 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:32 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:33 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:33 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:33 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:33 WARN DAGScheduler: Broadcasting large task binary with size 1795.1 KiB
# 24/12/13 02:53:34 WARN DAGScheduler: Broadcasting large task binary with size 1796.3 KiB
# 24/12/13 02:53:34 WARN DAGScheduler: Broadcasting large task binary with size 1860.9 KiB
# 24/12/13 02:54:45 WARN DAGScheduler: Broadcasting large task binary with size 1862.1 KiB
# Average metric [126.5802136340243]
# 24/12/13 02:54:46 WARN DAGScheduler: Broadcasting large task binary with size 1855.3 KiB
# +--------------------+---------------+------------------+----------------------------+-----------+-----------------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+------------------+
# |flightDate_OnWeekend|startingAirport|destinationAirport|travelduration_total_minutes|elapsedDays|daysBetweenFlight|isBasicEconomy|isNonStop|seatsRemaining|totalTravelDistance|segmentsArrivalAirportCode|segmentsCabinCode  |totalFare|prediction        |
# +--------------------+---------------+------------------+----------------------------+-----------+-----------------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+------------------+
# |1                   |ORD            |MIA               |186                         |0          |40               |0             |1        |2             |1192.0             |MIA                       |coach              |338.61   |230.18488851214988|
# |1                   |ORD            |MIA               |382                         |0          |40               |0             |0        |7             |1824.0             |JFK||MIA                  |coach||coach       |347.61   |292.6088808775346 |
# |1                   |ORD            |MIA               |388                         |0          |40               |0             |0        |9             |1824.0             |LGA||MIA                  |coach||coach       |328.6    |326.4171196873499 |
# |1                   |ORD            |MIA               |395                         |0          |40               |0             |0        |9             |1196.0             |ATL||MIA                  |coach||coach       |328.6    |383.0419258383273 |
# |1                   |ORD            |MIA               |443                         |0          |40               |0             |0        |9             |1824.0             |EWR||MIA                  |coach||coach       |357.6    |398.7029332619107 |
# |1                   |ORD            |MIA               |450                         |0          |40               |0             |0        |7             |1824.0             |JFK||MIA                  |coach||coach       |347.61   |297.2315221409092 |
# |1                   |ORD            |MIA               |425                         |0          |40               |0             |0        |9             |1824.0             |EWR||MIA                  |coach||coach       |357.6    |397.479292927488  |
# |1                   |ORD            |OAK               |627                         |0          |40               |0             |0        |3             |2285.0             |PDX||OAK                  |coach||coach       |547.2    |528.9678366682207 |
# |1                   |ORD            |OAK               |653                         |0          |40               |0             |0        |2             |1839.0             |SLC||OAK                  |coach||coach       |667.2    |483.50938879591246|
# |1                   |ORD            |OAK               |720                         |0          |40               |0             |0        |9             |2213.0             |MSP||LAX||OAK             |coach||coach||coach|725.1    |553.3562094137234 |
# |1                   |ORD            |OAK               |720                         |0          |40               |0             |0        |9             |2213.0             |MSP||LAX||OAK             |coach||coach||coach|725.1    |553.3562094137234 |
# |1                   |ORD            |OAK               |902                         |1          |40               |0             |0        |9             |2636.0             |AUS||SLC||OAK             |coach||coach||coach|767.7    |586.459582376681  |
# |1                   |ORD            |OAK               |1079                        |0          |40               |0             |0        |7             |2612.0             |SLC||SEA||OAK             |coach||coach||coach|666.09   |605.4516853647183 |
# |1                   |ORD            |OAK               |1109                        |0          |40               |0             |0        |5             |2592.0             |DEN||SEA||OAK             |coach||coach||coach|636.09   |561.4667957327056 |
# |1                   |ORD            |OAK               |442                         |0          |40               |0             |0        |7             |2285.0             |PDX||OAK                  |coach||coach       |627.6    |531.63036428664   |
# |1                   |ORD            |OAK               |499                         |0          |40               |0             |0        |7             |2395.0             |SEA||OAK                  |coach||coach       |627.6    |520.9455095255661 |
# |1                   |ORD            |OAK               |506                         |0          |40               |0             |0        |3             |2285.0             |PDX||OAK                  |coach||coach       |611.6    |520.7422544201571 |
# |1                   |ORD            |OAK               |595                         |0          |40               |0             |0        |9             |1919.0             |MSP||SLC||OAK             |coach||coach||coach|725.1    |658.8110552513933 |
# |1                   |ORD            |PHL               |644                         |1          |40               |0             |0        |7             |1142.0             |BOS||PHL                  |coach||coach       |312.19   |318.6355542632231 |
# |1                   |ORD            |PHL               |690                         |1          |40               |0             |0        |6             |1142.0             |BOS||PHL                  |coach||coach       |312.19   |317.95292735397356|
# +--------------------+---------------+------------------+----------------------------+-----------+-----------------+--------------+---------+--------------+-------------------+--------------------------+-------------------+---------+------------------+
# only showing top 20 rows
# 24/12/13 02:55:04 WARN DAGScheduler: Broadcasting large task binary with size 1861.7 KiB
# 24/12/13 02:55:51 WARN DAGScheduler: Broadcasting large task binary with size 1862.8 KiB
# 24/12/13 02:55:52 WARN DAGScheduler: Broadcasting large task binary with size 1861.7 KiB
# [Stage 446:===================================================>   (17 + 1) / 18]
# RMSE: 126.42186499823238  R-squared:0.5888456198011153
# 24/12/13 02:56:35 WARN DAGScheduler: Broadcasting large task binary with size 1862.8 KiB

# %%
print(bestModel.stages)

coefficients = bestModel.stages[5].coefficients
# print("bestModel coefficients", coefficients)
intercept = bestModel.stages[5].intercept
print("bestModel intercept", intercept)

#Finding the most important features
feature_names = ['daysBetweenFlight','flightDate_OnWeekend','startingAirport','destinationAirport', 'travelduration_total_minutes', 'elapsedDays', 'isBasicEconomy', 'isNonStop', 'seatsRemaining', 'totalTravelDistance', 'segmentsArrivalAirportCode', 'segmentsCabinCode']

coef_map = dict(zip(feature_names, coefficients))

print("Feature Importance:")
for feature, coef in coef_map.items():
    print("  {}: {:.3f}".format(feature, coef))
# Out:
# [StringIndexerModel: uid=StringIndexer_38ee4d757c47, handleInvalid=keep, numInputCols=4, numOutputCols=4, OneHotEncoderModel: uid=OneHotEncoder_ea99aafd2e53, dropLast=false, handleInvalid=error, numInputCols=4, numOutputCols=4, VectorAssembler_5d30dc43c88d, MinMaxScalerModel: uid=MinMaxScaler_dcf5a2cac5d7, numFeatures=1, min=0.0, max=1.0, VectorAssembler_8a67506af236, LinearRegressionModel: uid=LinearRegression_baa54bef0a6a, numFeatures=9962]
# bestModel intercept 214.20020853200674
# Feature Importance:
#   daysBetweenFlight: -2.303
#   flightDate_OnWeekend: -30.594
#   startingAirport: -17.899
#   destinationAirport: 21.581
#   travelduration_total_minutes: 2.663
#   elapsedDays: -11.458
#   isBasicEconomy: -21.501
#   isNonStop: 9.597
#   seatsRemaining: -15.074
#   totalTravelDistance: -36.939
#   segmentsArrivalAirportCode: 18.291
#   segmentsCabinCode: 15.833

# %%
transformed_sdf.write.parquet('gs://my-bigdata-project-rn/trusted/trusted_linear_itineraries.parquet')
# Out:
# 24/12/13 02:58:24 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 24/12/13 02:58:24 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB

# %%
model_path =  'gs://my-bigdata-project-rn/models/plane_linear_regression_model'
bestModel.write().overwrite().save(model_path)

# %%
1+1
# Out:
# 2
